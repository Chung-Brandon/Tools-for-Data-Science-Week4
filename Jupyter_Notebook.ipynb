# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Brandon Chung**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because data science is the process in which we can derive useful insights that were previously unseen. I hope to make a positive change in whatever industry I belong to in the future.*

# %% [markdown]
# ### Cell 5 is supposed to return the solution to the basic arithmatic problem : 5 times 5

# %%
5*5
# Out:
# 25

# %% [markdown]
# == Things that I like ==
#
# ---
#
# * dogs
# * cats
# * pets
