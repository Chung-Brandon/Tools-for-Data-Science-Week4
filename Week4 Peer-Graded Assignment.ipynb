# %% [markdown]
# # Tools for Data Science Peer-Graded Assignment

# %% [markdown]
# Hi, I am excided to begin my data science journey with you all. My name is Brandon and this is my peer-graded assingment introduction.

# %% [markdown]
# Data Science Languages:
# 1. SQL
# 2. R
# 3. VBA
# 4. Python
# 5. Go
# 6. Scala
# 7. MATLAB

# %% [markdown]
# Data Science Libraries
# 1. TensorFlow
# 2. NumPy
# 3. Pandas
# 4. Matplotlib
# 5. PyTorch
# 6. Plotly

# %% [markdown]
# | Tool        |            Use |
# |:---         |            ---:|
# |Scrapy       |    Web Scraping|
# |Tensorflow   | Neural Networks|
# |Apache Spark | Data Processing|

# %% [markdown]
# Arithmetic Expression Examples
#
# ---
#
# addition ( + ) example: 5+5
#
# multiplication ( * ) example: 5*5
#
# subtraction ( - ) example: 5-5
#
# division ( / ) example: 5/5

# %%
x = 5*5 
y= x + 5

print(y)
# Out:
# 30

# %%
minutes = 167

hours = minutes//60
minutes = minutes % 60

print ("number of hours", hours)
print ("remaining minutes", minutes)
# Out:
# number of hours 2
# remaining minutes 47

# %% [markdown]
# Objectives List
#
# ---
# 1. Learn Python Tools
# 2. Learn Markdown Tools
# 3. Familiarize myself with juypter notebooks
# 4. Begin using Github

# %% [markdown]
# Author: Brandon Chung
